# %% [markdown]
# ![](https://matplotlib.org/3.1.0/_static/logo2.png)

# %% [markdown]
# # *Introduction*
#
# Matplotlib is one of the most popular Python packages used for data visualization. It is a cross-platform library for making 2D plots from data in arrays.
#
# Humans are very visual creatures: we understand things better when we visualize them. However, the step to presenting analyses, results or insights can be a bottleneck: you might not even know where to start from or you might have already the right format in mind, but then questions like “Is this the right visual insights I want to bring to my audience?” will have definitely cross your mind.
#
# When you’re working with the Python plotting library Matplotlib, the first step to answering the above questions is by building up knowledge on topics like:
#
# * what is a subplot? What are the Axes? What exactly is a figure?
# * which module do we need to import?
# * Basic plot customizations, with a focus on plot legends and text, titles, axes labels and plot layout.
# * Saving, showing, clearing, … your plots
# * ...

# %% [markdown]
# # *Installation Guide*

# %%
#!pip3 install matplotlib

# %% [markdown]
# # *Import Matplotlib*

# %%
import matplotlib

# %% [markdown]
# # *Checking Matplotlib Version*

# %%
print(matplotlib.__version__)
# Out:
# 3.2.2

# %% [markdown]
# # *Pyplot*
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
#Now the Pyplot package can be referred to as plt.
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # *simple plot*

# %%
# To begin with, we create a figure instance which provides an empty canvas.

fig = plt.figure()

# %% [markdown]
# Now add axes to figure. The add_axes() method requires a list object of 4 elements corresponding to left, bottom, width and height of the figure. Each number must be between 0 and 1 −

# %%
ax = fig.add_axes([0,0,1,1])

# %%
fig.add_axes?

# %%
# Set labels for x and y axis as well as title −

ax.set_title("sine wave")
ax.set_xlabel('angle')
ax.set_ylabel('sine')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e4a218025bf5> in <module>()
#       1 # Set labels for x and y axis as well as title −
#       2
# ----> 3 ax.set_title("sine wave")
#       4 ax.set_xlabel('angle')
#       5 ax.set_ylabel('sine')
#
# NameError: name 'ax' is not defined

# %%
# ax.plot(x,y)
plt.show?

# %%
# or we can define what x and y
xpoints = np.array([0, 3])
ypoints = np.array([1,4])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3, (etc. depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
# Default X-Points
plt.figure(figsize=(8,6), dpi=100)

plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
# plot is a versatile function, and will take an arbitrary number of arguments. For example, to plot x versus y, you can write:

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
plt.plot(X,C)
plt.plot(X,S)

plt.show()

# %% [markdown]
# # *Multiple Points*
# You can plot as many points as you like, just make sure you have the same number of points in both axes.

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# How do we plot it with Default X-Points

###############################################################################

plt.plot(ypoints)
plt.show()


###############################################################################

# %% [markdown]
# # *Formatting the style of your plot 'Markers'*
#
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %%
# Mark each point with a circle:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
#Mark each point with a star:
plt.plot(ypoints, marker = '*')

# %% [markdown]
# ###Format Strings fmt
# **bold text**
# You can use also use the shortcut string notation parameter to specify the marker. This parameter is also called fmt, and is written with this syntax: marker|line|color

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# ###Marker Size
# You can use the keyword argument markersize or the shorter version, ms to set the size of the markers:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# ###Marker Color
# You can use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers:**bold text**

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
# You can use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# ##Linestyle
#
# You can use the keyword argument linestyle, or shorter 'ls', to change the style of the plotted line:

# %%
# Use a dotted line:
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
#plt.plot(ypoints, ls = ':')
plt.show()

# %%
# plt.plot(ypoints, linestyle = 'dashed')
plt.plot(ypoints, '--')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # 'bo', 'r+', 'go--'', +++
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ###Line Color
# You can use the keyword argument color or the shorter c to set the color of the line:

# %%
#You can use the keyword argument color or the shorter c to set the color of the line:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# ###Line Width
# You can use the keyword argument linewidth or the shorter lw to change the width of the line.
#
# The value is a floating number, in points:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %%
# plot using different styles:  red dashes (t), blue squares (t^2) and green triangles (t^3)

t = np.arange(0., 5., 0.2)
###############################################################################
plt.plot(t, t, 'r--')
plt.plot(t, t**2, 'bs')
plt.plot(t, t**3, 'g^')
plt.show()
###############################################################################

# %%
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# ##Multiple Lines
# You can plot as many lines as you like by simply adding more plt.plot() functions:

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
# Nice exercies
# Play around the colors, line widths and line style for the functions bellow
# As a first step, we want to have the cosine in blue and the sine in red, choose different line style and a slightly thicker line for both of them. 
# We'll also slightly alter the figure size to make it more horizontal.

##############################################################################
X = np.linspace(0, 2*np.pi, 100)
C = np.cos(X)
S = np.sin(X)
plt.plot(X, C, label='Cos x', color="blue", linewidth=2, linestyle=":")
plt.plot(X, S, label='Sin x', color="red",  linewidth=2, linestyle="--")
plt.legend()
plt.show()

###############################################################################
#################################################################################

# %%
# Adding a legend
plt.figure(figsize=(20,6), dpi=100)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-", label="sine")

plt.legend(loc='upper left')
plt.show()

# %%
plt.legend?

# %%
# We can get more info here
plt.plot?

# %% [markdown]
# #*Create Title and Labels for a Plot*
#
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'Times New Roman','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #*Multiple plots in one figure:*
# The subplots() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.

# %%
plt.figure(figsize=(12,2), dpi=80)
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)


# Plot 1:
C = np.cos(X)
plt.subplot(1, 2, 1)  #the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(X, C, label='Cos x', color="blue", linewidth=2.5, linestyle="-")
plt.legend()

# Plot 2:
S = np.sin(X)
plt.subplot(1, 2, 2) #the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(X, S, label='Sin x', color="red",  linewidth=2.5, linestyle="--")
plt.legend()


plt.show()

# %%
plt.figure(figsize=(6,4), dpi=80)
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)

font = {'family':'serif','color':'black','size':15}

# Plot 1:
C = np.cos(X)
plt.subplot(2, 1, 1)  #the figure has 2 row, 2 columns, and this plot is the first plot.
plt.plot(X, C, label='Cos x', color="blue", linewidth=2.5, linestyle="-")
plt.legend()
plt.title("Trig functions", fontdict = font)

# Plot 2:
S = np.sin(X)
plt.subplot(2, 1, 2) #the figure has 2 row, 1 columns, and this plot is the second plot.
plt.plot(X, S, label='Sin x', color="red",  linewidth=2.5, linestyle="--")
plt.legend()

plt.show()

# %%
# Draw 6 plots subplots and a title to it?
###############################################################################
plt.figure(figsize=(12,8), dpi=100)
font_st = {'family':'serif','color':'black','size':30}
plt.suptitle('Trigonometric Functions and thier Inverses', fontsize=20)


X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
font = {'family':'serif','color':'black','size':15}

# Left plots:
#   Sin (x)
S = np.sin(X)
plt.subplot(3, 2, 1)  #the figure has 2 row, 2 columns, and this plot is the first plot.
plt.plot(X, S, label='sin x', color="red", linewidth=2.5, linestyle=":")
plt.legend()
plt.grid()
plt.title("Trig Functions", fontdict = font)

#   Cos (x)
C = np.cos(X)
plt.subplot(3, 2, 3)  #the figure has 2 row, 2 columns, and this plot is the first plot.
plt.plot(X, C, label='Cos x', color="green", linewidth=2.5, linestyle="--")
plt.legend()
plt.grid()

#   Cos (x)
T = np.tan(X)
plt.subplot(3, 2, 5)  #the figure has 2 row, 2 columns, and this plot is the first plot.
plt.plot(X, T, label='Tan x', color="blue", linewidth=2.5, linestyle="-")
plt.legend()
plt.grid()


# Right plots:
#   Sin (x)
AS = np.arcsin(X)
plt.subplot(3, 2, 2)  #the figure has 2 row, 2 columns, and this plot is the first plot.
plt.plot(X, AS, label='$sin^{-1} x$', color="red", linewidth=2.5, linestyle=":")
plt.legend()
plt.grid()
plt.title("Inverse Trig Functions", fontdict = font)

#   Cos (x)
AC = np.arccos(X)
plt.subplot(3, 2, 4)  #the figure has 2 row, 2 columns, and this plot is the first plot.
plt.plot(X, AC, label='$Cos^{-1} x$', color="green", linewidth=2.5, linestyle="--")
plt.legend()
plt.grid()

#   Cos (x)
AT = np.arctan(X)
plt.subplot(3, 2, 6)  #the figure has 2 row, 2 columns, and this plot is the first plot.
plt.plot(X, AT, label='$Tan^{-1} x$', color="blue", linewidth=2.5, linestyle="-")
plt.legend()
plt.grid()



plt.show()
###############################################################################
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in arcsin
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in arccos

# %%
# can we have a super title to the figure and a title to the entire figures?how?

# %% [markdown]
# You can add an insert plot in the same figure by adding another axes object in the same figure canvas.

# %%
import math

x = np.arange(0, math.pi*2, 0.05)

fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.55, 0.55, 0.3, 0.3]) # inset axes

axes1.plot(x, np.sin(x), 'b')
axes1.set_title('sine')

axes2.plot(x,np.cos(x),'r')
axes2.set_title("cosine")


plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_subplot(111)
ax1.plot([1,2,3])

ax2 = fig.add_subplot(221, facecolor='#FCF4A3')
ax2.plot([1,2,3])

plt.show()

# %%
fig.add_subplot?

# %% [markdown]
# # *Plotting with categorical variables*
# *1.* Bar **Graphs**

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, color =  'red')   # Horizontal Bars, you can also play around the color, height and the width
plt.show()

# %% [markdown]
# *2.* Histogram

# %%
np.random.normal?

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x, width=2)
plt.show()

# %% [markdown]
# *3.* Scatter plot
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# *3.* Pie Charts

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# As you can see the pie chart draws one piece (called a wedge) for each value in the array (in this case [35, 25, 25, 15]).
#
# By default the plotting of the first wedge starts from the x-axis and move counterclockwise:

# %%
# we can also add label to the pie chart
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y , labels = mylabels)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# *4* Contour Plots

# %%
def f(x,y): return (1 - x/2 + x**5 + y**3)*np.exp(-x**2 - y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y) # I really like it 

plt.contourf(X, Y, f(X,Y), 8, alpha=.75, cmap='jet')
plt.contour(X, Y, f(X,Y), 8, colors='black', linewidths=1.5)
plt.show()

# %%
# create a one plot that contain different categorical variables and add a title to it?
# hint in  Matplotlib allows you to pass categorical variables directly to many plotting functions. 

##############################################################################
cat1 = ['Sad :(', 'Normal :|', 'Happy :)']
val1 = [20, 10, 30]
cat2 = ['Cry ;(', 'Wonder :o', 'Lough :D']
val2 = [25, 35, 40]

fig = plt.figure(figsize=(8,2), dpi=100)

fig.add_subplot(1,2,1)
plt.bar(cat1, val1)


fig.add_subplot(1,2,2)
plt.pie(val2, labels=cat2)


plt.show()
###############################################################################

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# ##Matplotlib - Three-dimensional Plotting
#
# Even though Matplotlib was initially designed with only two-dimensional plotting in mind, some three-dimensional plotting utilities were built on top of Matplotlib's two-dimensional display in later versions, to provide a set of tools for three-dimensional data visualization. Three-dimensional plots are enabled by importing the mplot3d toolkit, included with the Matplotlib package.
#
# A three-dimensional axes can be created by passing the keyword projection='3d' to any of the normal axes creation routines.

# %%
from mpl_toolkits import mplot3d

fig = plt.figure()
ax = plt.axes(projection='3d')
z = np.linspace(0, 1, 100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)
c = x + y

ax.scatter(x, y, z, c=c) #ax.plot3D(x, y, z, 'gray') # we can change it from RGB  to gray by using 'gray'
ax.set_title('3D line plot')
# ax.xlabel('X')


plt.show()

# %%
# Matplotlib - 3D Surface plot

x = np.outer(np.linspace(-2, 2, 30), np.ones(30))
y = x.copy().T # transpose
z = np.cos(x ** 2 + y ** 2)

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none')
ax.set_title('Surface plot')
plt.show()

# %% [markdown]
# #*Working with image*

# %%
import matplotlib.image as mpimg

# %%
# Importing image data into Numpy arrays
from skimage import io, color
plt.figure(figsize=(10,5))
img = io.imread('https://matplotlib.org/3.1.0/_static/logo2.png')
plt.imshow(img)

# %%
plt.imsave("logo.png", img, cmap = 'hot', origin = 'lower')

# %%
plt.figure(figsize=(10,5))
img2 = mpimg.imread('/content/logo.png')
plt.imshow(img2)

# %% [markdown]
# ##Applying pseudocolor schemes to image plots¶
# Pseudocolor can be a useful tool for enhancing contrast and visualizing your data more easily. This is especially useful when making presentations of your data using projectors - their contrast is typically quite poor.
#
# Pseudocolor is only relevant to single-channel, grayscale, luminosity images. We currently have an RGB image. Since R, G, and B are all similar (see for yourself above or in your data), we can just pick one channel of our data:

# %%
lum_img = img[:, :, 3]

# This is array slicing.  You can read more in the `Numpy tutorial
# <https://docs.scipy.org/doc/numpy/user/quickstart.html>`_.

plt.imshow(lum_img)

# %% [markdown]
# Now, with a luminosity (2D, no color) image, the default colormap (aka lookup table, LUT), is applied. The default is called viridis. There are plenty of others to choose from.

# %%
plt.imshow(lum_img, cmap="hot")

# %%
# Note that you can also change colormaps on existing plot objects using the set_cmap() method:

imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %% [markdown]
# ###Note
# ####However, remember that in the Jupyter Notebook with the inline backend, you can't make changes to plots that have already been rendered. If you create imgplot here in one cell, you cannot call set_cmap() on it in a later cell and expect the earlier plot to change. Make sure that you enter these commands together in one cell. plt commands will not change plots from earlier cells.

# %% [markdown]
# ## Color scale reference
# It's helpful to have an idea of what value a color represents. We can do that by adding a color bar to your figure

# %%
plt.imshow(img)
plt.colorbar()

# %% [markdown]
# # *Matplotlib - Working With Text*
#
# The user has a great deal of control over text properties (font size, font weight, text location and color, etc.). Matplotlib implements a large number of TeX math symbols and commands, such as text, xlabel, ylabel, title, figtext, suptitle .....

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.set_title('axes title')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')

ax.text(3, 8, 'boxed italics text in data coords', style='italic', bbox = {'facecolor': 'red'})

ax.text(2, 6, r'an equation: $E = mc^2$', fontsize = 15)

ax.text(4, 0.05, 'colored text in axes coords',

verticalalignment = 'bottom', color = 'green', fontsize = 15)

ax.plot([2], [1], 'o')

ax.annotate('annotate', xy = (2, 1), xytext = (3, 4), arrowprops = dict(facecolor = 'black', shrink = 0.05))

ax.axis([0, 10, 0, 10])


plt.show()

# %%
# math text
plt.title(r'$\alpha > \beta$')
# Out:
# Text(0.5, 1.0, '$\\alpha > \\beta$')

# %%
r'$\alpha_i> \beta_i$'

import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)

plt.plot(t,s)
plt.title(r'$\alpha_i> \beta_i$', fontsize=20)

plt.text(0.6, 0.6, r'$\mathcal{A}\mathrm{sin}(2 \omega t)$', fontsize = 20)
plt.text(0.1, -0.5, r'$\sqrt{2}$', fontsize=10)
plt.xlabel('time (s)')
plt.ylabel('volts (mV)')
plt.show()

# %% [markdown]
# #Summary
#
# * plot(x-axis values, y-axis values) — plots a simple line graph with x-axis values against y-axis values
#
# * show() — displays the graph
# * title(“string”) — set the title of the plot as specified by the string
# * xlabel(“string”) — set the label for x-axis as specified by the string
# * ylabel(“string”) — set the label for y-axis as specified by the string
# * figure() — used to control a figure level attributes
# * subplot(nrows, ncols, index) — Add a subplot to the current figure
# * suptitle(“string”) — It adds a common title to the figure specified by the string
# * subplots(nrows, ncols, figsize) — a convenient way to create subplots, in a single call. It returns a tuple of a figure and number of axes.
# * set_title(“string”) — an axes level method used to set the title of subplots in a figure
# * bar(categorical variables, values, color) — used to create vertical bar graphs
# * barh(categorical variables, values, color) — used to create horizontal bar graphs
# * legend(loc) — used to make legend of the graph
# * xticks(index, categorical variables) — Get or set the current tick locations and labels of the x-axis
# * pie(value, categorical variables) — used to create a pie chart
# * hist(values, number of bins) — used to create a histogram
# * xlim(start value, end value) — used to set the limit of values of the x-axis
# *ylim(start value, end value) — used to set the limit of values of the y-axis
# * scatter(x-axis values, y-axis values) — plots a scatter plot with x-axis values against y-axis values
# *axes() — adds an axes to the current figure
# * set_xlabel(“string”) — axes level method used to set the x-label of the plot specified as a string
# *set_ylabel(“string”) — axes level method used to set the y-label of the plot specified as a string
# * scatter3D(x-axis values, y-axis values) — plots a three-dimensional scatter plot with x-axis values against y-axis values
# * plot3D(x-axis values, y-axis values) — plots a three-dimensional line graph with x-axis values against y-axis values

# %% [markdown]
# #*Refrences*
#
# * https://www.w3schools.com/python/matplotlib_intro.asp
# * https://towardsdatascience.com/matplotlib-tutorial-learn-basics-of-pythons-powerful-plotting-library-b5d1b8f67596

# %% [markdown]
# #*Some nice exercises*
# #*Exercise 1*
# Create a figure of size 15x8 with two subplots, top and bottom.
# Draw two lines in the top axes, one green and one orange.
# Add a legend for the top plot, Green and Orange. Put this legend in the top-middle of graph.
# Extra Challenge: In the bottom axes, create a graph of only the data points, marked by circles, but with no line connecting the points.

# %%
# Before we start anything, let's create some sample data for our plotting.
import pandas as pd
import seaborn as sns
df = pd.DataFrame(data={'a':np.random.randint(0, 100, 30),
                        'b':np.random.randint(0, 100, 30),
                        'c':np.random.randint(0, 100, 30)})
df.head()
# Out:
#     a   b   c
# 0  47  50   1
# 1   3  98  71
# 2  28  17  42
# 3  29  63  15
# 4  45   9  11

# %%
# My Sample Answer
fig, ax = plt.subplots(2, 1, figsize=(15,8))

ax[0].plot(df.index.values, df['a'], c='green')
ax[0].plot(df.index.values, df['b'], c='orange')
ax[0].legend(loc=9) # "9": upper center

ax[1].plot(df.index.values, df['c'], marker='o', lw=0) # set line width = 0, means no visuable line
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #*Exercise 2*
# Create a figure with three subplots, aligned vertically.
# Create a bar graph for a and b on the first two, but at the last one draw both a and b, but put b on top of a! (Hint: use the bottom argument in the bar function)
# Make sure the color for a and b are consistent in all the subplots!
# Extra Challenge: Write the magnitude of each bar on top of it

# %%
# My Sample Answer
fig, ax = plt.subplots(3, 1, figsize=(15,18))

ax[0].bar(df.index.values, df['a'])
for i in range(df.shape[0]):
    ax[0].text(i, df['a'][i]+1, df['a'][i], horizontalalignment='center')
ax[0].legend('a')
    
ax[1].bar(df.index.values, df['b'])
for i in range(df.shape[0]):
    ax[1].text(i, df['b'][i]+1, df['b'][i], horizontalalignment='center')
ax[1].legend('b')

ax[2].bar(df.index.values, df['a'])
ax[2].bar(df.index.values, df['b'], bottom=df['a'])
for i in range(df.shape[0]):
    ax[2].text(i, df['a'][i]+df['b'][i]+1, df['a'][i]+df['b'][i], horizontalalignment='center')
ax[2].legend(['a','b'])

# %% [markdown]
# #*Exercise 3*
# Visualize the mock data given below.
# Create bars to represent the turnover for each market.
# Keep in mind that showing too much information on a graph can be overwhelming, so do it with discretion !
# Use labels to make sure your audience understands the graph.
# Extra Challenge: On the opposite axis, draw a line to show each market share. (Hint: use ax.twinx())

# %%
# mock data
np.random.seed(0)

turnover_data = pd.DataFrame({'boardid' : ['DAY', 'DAY_X', 'DAY_U', 'TSE'], 
                              'turnover' : np.random.randint(1e6, 1e9, 4)})

# sort by turnover value
turnover_data = turnover_data.sort_values(by='turnover').reset_index().drop('index', axis=1)

# convert value to Million unit for easy-reading
turnover_data['turnover_simplified'] = turnover_data['turnover'] // 1000000

# market share
turnover_data['market_share'] = round((turnover_data['turnover'] / sum(turnover_data['turnover'])*100), 1)

turnover_data
# Out:
#   boardid   turnover  turnover_simplified  market_share
# 0     DAY  210652396                  210          10.8
# 1   DAY_X  399764591                  399          20.6
# 2     TSE  405868288                  405          20.9
# 3   DAY_U  925231285                  925          47.7

# %%
# My Sample Answer
fig, ax1 = plt.subplots(figsize=(15,10))

ax1.bar(turnover_data['boardid'], turnover_data['turnover'], width=0.5, color='lightgreen')
for i in range(turnover_data.shape[0]):
    ax1.text(turnover_data['boardid'][i], turnover_data['turnover'][i]+1e7, str(turnover_data['turnover_simplified'][i])+'M', fontsize=15, horizontalalignment='center')

ax1.set_title('Turnover Data', fontsize=20)
ax1.set_xticklabels(turnover_data['boardid'], fontsize=15);

ax1.tick_params(labelsize=15, axis='y')

ax1.set_ylabel('Turnover Values(Million)', fontsize=20)
ax1.set_ylim(0, max(turnover_data['turnover']+1e8))

# Format ax1 y axis - method 1
vals = ax1.get_yticks()
ax1.set_yticklabels([str(x/1000000)+'M' for x in vals])


ax2 = ax1.twinx()
ax2.plot(turnover_data['boardid'], turnover_data['market_share'], c='red', lw=4, marker='o')
for i in range(turnover_data.shape[0]):
    ax2.text(turnover_data['boardid'][i], turnover_data['market_share'][i]+1, str(turnover_data['market_share'][i])+'%', fontsize=15, horizontalalignment='center', color='black')

ax2.set_ylabel('Market Shares(%)', fontsize=20)
ax2.tick_params(labelsize=15, axis='y', rotation=30)

# Format ax2 y asix - method 1
# ax2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y/100)))

# Format ax2 y asix - method 2
vals = ax2.get_yticks()
ax2.set_yticklabels([str(x)+'%' for x in vals]);
